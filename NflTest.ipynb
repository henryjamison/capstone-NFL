# %%
import pandas as pd

# url = 'https://www.pro-football-reference.com/players/M/MahoPa00/fantasy/'
# df = pd.read_html(url)[0]
# df
df_2022 = pd.read_csv('2022_fantasy.csv')
print(df_2022.to_html())
# Out:
#       Rk                Player   Tm FantPos  Age   G  GS  Cmp  Att   Yds  ...  \
# 0      1     Patrick Mahomes*+  KAN      QB   27  17  17  435  648  5250  ...
# 1      2         Josh Jacobs*+  LVR      RB   24  17  17    0    0     0  ...
# 2      3  Christian McCaffrey*  2TM      RB   26  17  16    1    1    34  ...
# 3      4        Derrick Henry*  TEN      RB   28  16  16    2    2     4  ...
# 4      5    Justin Jefferson*+  MIN      WR   23  17  17    2    2    34  ...
# ..   ...                   ...  ...     ...  ...  ..  ..  ...  ...   ...  ...
# 645  646       Braylon Sanders  MIA      WR   23   3   0    0    0     0  ...
# 646  647  Ihmir Smith-Marsette  2TM      WR   23   8   0    0    0     0  ...
# 647  648          Deonte Harty  NOR      WR   25   4   0    0    0     0  ...
# 648  649      KaVontae Turpin*  DAL      WR   26  17   0    0    0     0  ...
# 649  650        Chester Rogers  CLE     NaN   28   3   0    0    0     0  ...
#
#      2PM  2PP  FantPt    PPR   DKPt   FDPt    VBD  PosRank  OvRank▲     -9999
# 0    1.0  2.0   416.0  417.4  435.4  428.9  136.0        1      1.0  MahoPa00
# 1    NaN  NaN   275.0  328.3  335.3  301.8  127.0        1      2.0  JacoJo01
# 2    NaN  NaN   271.0  356.4  362.4  313.9  123.0        2      3.0  McCaCh01
# 3    NaN  NaN   270.0  302.8  311.8  286.3  122.0        3      4.0  HenrDe00
# 4    1.0  NaN   241.0  368.7  371.7  304.7  119.0        1      5.0  JeffJu00
# ..   ...  ...     ...    ...    ...    ...    ...      ...      ...       ...
# 645  NaN  NaN     NaN    1.7    2.7    0.7    NaN      251      NaN  SandBr00
# 646  NaN  NaN    -1.0    0.4    1.4   -0.1    NaN      252      NaN  SmitIh00
# 647  NaN  NaN    -1.0    1.3    2.3    0.3    NaN      253      NaN  HarrDe07
# 648  NaN  NaN    -1.0   -0.4    1.6   -0.9    NaN      254      NaN  TurpKa00
# 649  NaN  NaN    -2.0   -2.0   -1.0   -2.0    NaN      255      NaN  RogeCh02
#
# [650 rows x 34 columns]

# %%
df_2021 = pd.read_csv('2021_fantasy.csv')
df_2021
# Out:
#       Rk             Player   Tm FantPos  Age   G  GS    Cmp    Att     Yds  \
# 0      1  Jonathan Taylor*+  IND      RB   22  17  17    0.0    0.0     0.0
# 1      2      Cooper Kupp*+  LAR      WR   28  17  17    0.0    1.0     0.0
# 2      3     Deebo Samuel*+  SFO      WR   25  16  15    1.0    2.0    24.0
# 3      4         Josh Allen  BUF      QB   25  17  17  409.0  646.0  4407.0
# 4      5      Austin Ekeler  LAC      RB   26  16  16    0.0    0.0     0.0
# ..   ...                ...  ...     ...  ...  ..  ..    ...    ...     ...
# 664  665    Travis Benjamin  SFO     NaN   32  10   0    0.0    0.0     0.0
# 665  666     Trenton Cannon  2TM      RB   27  12   0    0.0    0.0     0.0
# 666  667       John Wolford  LAR      QB   26   3   0    1.0    4.0     5.0
# 667  668         Josh Rosen  ATL      QB   24   4   0    2.0   11.0    19.0
# 668  669    Diontae Spencer  DEN      WR   29  15   0    0.0    0.0     0.0
#
#      ...  2PM  2PP  FantPt    PPR   DKPt   FDPt    VBD  PosRank  OvRank  \
# 0    ...  NaN  NaN   333.0  373.1  381.1  353.1  176.0        1     1.0
# 1    ...  1.0  NaN   295.0  439.5  442.5  367.0  163.0        1     2.0
# 2    ...  NaN  NaN   262.0  339.0  347.0  300.5  132.0        2     3.0
# 3    ...  2.0  1.0   403.0  402.6  426.6  417.6  126.0        1     4.0
# 4    ...  2.0  NaN   274.0  343.8  352.8  308.8  120.0        2     5.0
# ..   ...  ...  ...     ...    ...    ...    ...    ...      ...     ...
# 664  ...  NaN  NaN    -2.0   -2.0   -1.0   -2.0    NaN      260     NaN
# 665  ...  NaN  NaN    -2.0   -1.6   -0.6   -1.6    NaN      179     NaN
# 666  ...  NaN  NaN    -2.0   -1.9   -0.9   -0.9    NaN       84     NaN
# 667  ...  NaN  NaN    -3.0   -3.2   -1.2   -1.2    NaN       85     NaN
# 668  ...  NaN  NaN    -4.0   -3.3   -1.3   -3.8    NaN      261     NaN
#
#      PlayerID
# 0    TaylJo02
# 1    KuppCo00
# 2    SamuDe00
# 3    AlleJo02
# 4    EkelAu00
# ..        ...
# 664  BenjTr00
# 665  CannTr00
# 666  WolfJo00
# 667  RoseJo01
# 668  SpenDi00
#
# [669 rows x 34 columns]

# %%
# from bs4 import BeautifulSoup
# import requests

# url = 'https://www.pro-football-reference.com'
# year = 2018
# maxp = 300
    
# # grab fantasy players
# r = requests.get(url + '/years/' + str(year) + '/fantasy.htm')
# soup = BeautifulSoup(r.content, 'html.parser')
# parsed_table = soup.find_all('table')[0]  

# df = []

# # first 2 rows are col headers
# for i,row in enumerate(parsed_table.find_all('tr')[2:]):
#     if i % 10 == 0: print(i, end=' ')
#     if i >= maxp: 
#         print('\nComplete.')
#         break
        
#     try:
#         dat = row.find('td', attrs={'data-stat': 'player'})
#         name = dat.a.get_text()
#         stub = dat.a.get('href')
#         stub = stub[:-4] + '/fantasy/' + str(year)
#         pos = row.find('td', attrs={'data-stat': 'fantasy_pos'}).get_text()

#         # grab this players stats
#         tdf = pd.read_html(url + stub)[0]    

#         # get rid of MultiIndex, just keep last row
#         tdf.columns = tdf.columns.get_level_values(-1)

#         # fix the away/home column
#         tdf = tdf.rename(columns={'Unnamed: 4_level_2': 'Away'})
#         tdf['Away'] = [1 if r=='@' else 0 for r in tdf['Away']]

#         # drop all intermediate stats
#         tdf = tdf.iloc[:,[1,2,3,4,5,-3]]
        
#         # drop "Total" row
#         tdf = tdf.query('Date != "Total"')
        
#         # add other info
#         tdf['Name'] = name
#         tdf['Position'] = pos
#         tdf['Season'] = year

#         df.append(tdf)
#     except:
#         pass
    
# df = pd.concat(df)
# df.head()

# %%
# Out:
#                      Team  Fan Pts Agnst Tackles  Turnover Score  Ret  Points  \
# 0      Indianapolis Colts                  11.76              32   60      20
# 1          Houston Texans                  10.35              31   38      19
# 2           Chicago Bears                   9.35              30   58      15
# 3          Denver Broncos                   9.18              29   63      15
# 4        Los Angeles Rams                   9.06              28   59      15
# 5           New York Jets                   8.24              26   42      14
# 6        Tennessee Titans                   8.24              26   49      11
# 7   Washington Commanders                   8.12              25   48      16
# 8      New Orleans Saints                   8.06              24   38      14
# 9       Arizona Cardinals                   7.94              22   46      17
# 10   New England Patriots                   7.94              22   41      14
# 11      Minnesota Vikings                   7.06              21   47      15
# 12       Seattle Seahawks                   6.71              20   46      12
# 13      Carolina Panthers                   6.47              18   36      13
# 14      Las Vegas Raiders                   6.47              18   35      17
# 15    Pittsburgh Steelers                   6.35              17   38      14
# 16       Cleveland Browns                   6.06              14   44      12
# 17       Baltimore Ravens                   6.06              14   38      13
# 18         Miami Dolphins                   6.06              14   35      15
# 19      Green Bay Packers                   5.82              13   32      12
# 20        New York Giants                   5.53              12   49       6
# 21        Atlanta Falcons                   5.47              11   37       9
# 22   Los Angeles Chargers                   5.24               9   39      10
# 23         Dallas Cowboys                   5.24               9   27      18
# 24    Philadelphia Eagles                   5.18               8   44       9
# 25   Tampa Bay Buccaneers                   5.12               7   22      10
# 26     Cincinnati Bengals                   5.06               6   44      12
# 27          Buffalo Bills                   4.59               5   33      14
# 28   Jacksonville Jaguars                   4.47               4   28       9
# 29          Detroit Lions                   4.41               3   24       7
# 30    San Francisco 49ers                   3.94               2   31       9
# 31     Kansas City Chiefs                   3.41               1   26      12
#
#     Avg Rnk Sack Int  Fum Rec  TD  Saf  TD.1  Pts Allow
# 0    14   5    0   0      271 NaN  NaN   NaN        NaN
# 1     9   7    -   1      281 NaN  NaN   NaN        NaN
# 2    10   3    -   1      326 NaN  NaN   NaN        NaN
# 3     9   3    -   -      285 NaN  NaN   NaN        NaN
# 4     8   3    1   -      301 NaN  NaN   NaN        NaN
# 5     9   -    1   2      286 NaN  NaN   NaN        NaN
# 6    12   3    -   -      286 NaN  NaN   NaN        NaN
# 7     7   2    1   -      301 NaN  NaN   NaN        NaN
# 8    11   4    -   -      324 NaN  NaN   NaN        NaN
# 9     8   2    -   -      310 NaN  NaN   NaN        NaN
# 10    9   2    -   3      322 NaN  NaN   NaN        NaN
# 11    8   3    -   1      418 NaN  NaN   NaN        NaN
# 12   11   2    1   -      395 NaN  NaN   NaN        NaN
# 13    8   2    -   -      329 NaN  NaN   NaN        NaN
# 14    4   3    -   -      377 NaN  NaN   NaN        NaN
# 15    5   1    -   -      302 NaN  NaN   NaN        NaN
# 16    9   -    1   -      343 NaN  NaN   NaN        NaN
# 17    8   1    -   -      350 NaN  NaN   NaN        NaN
# 18    6   2    2   1      371 NaN  NaN   NaN        NaN
# 19   10   2    -   -      356 NaN  NaN   NaN        NaN
# 20   10   -    1   -      353 NaN  NaN   NaN        NaN
# 21   12   -    -   -      345 NaN  NaN   NaN        NaN
# 22    9   1    -   -      383 NaN  NaN   NaN        NaN
# 23    5   3    -   -      449 NaN  NaN   NaN        NaN
# 24   10   3    1   -      465 NaN  NaN   NaN        NaN
# 25   12   -    -   -      307 NaN  NaN   NaN        NaN
# 26    6   3    -   -      412 NaN  NaN   NaN        NaN
# 27   13   1    1   -      445 NaN  NaN   NaN        NaN
# 28   13   -    -   -      380 NaN  NaN   NaN        NaN
# 29    8   3    1   -      445 NaN  NaN   NaN        NaN
# 30    8   1    2   -      432 NaN  NaN   NaN        NaN
# 31   11   -    -   -      482 NaN  NaN   NaN        NaN

# %%
df_2021['PlayerID']
# Out:
# 0      TaylJo02
# 1      KuppCo00
# 2      SamuDe00
# 3      AlleJo02
# 4      EkelAu00
#          ...
# 664    BenjTr00
# 665    CannTr00
# 666    WolfJo00
# 667    RoseJo01
# 668    SpenDi00
# Name: PlayerID, Length: 669, dtype: object

# %%
# user_id = df_2021['PlayerID'][0]
# year = 2021
# https://www.pro-football-reference.com/players/M/TaylJo02/fantasy/2021/
# url = 'https://www.pro-football-reference.com/players/M/{}/fantasy/{}/'.format(user_id,year)
# df = pd.read_html(url)[0]
# df
# html = requests.get(url).text
# soup = BeautifulSoup(html, 'html.parser')
# rows = soup.find('table').find_all('td')
# rows
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#    Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
#                    Rk                 G#               Date
# 0                 1.0                1.0         2021-09-12
# 1                 2.0                2.0         2021-09-19
# 2                 3.0                3.0         2021-09-26
# 3                 4.0                4.0         2021-10-03
# 4                 5.0                5.0         2021-10-11
# 5                 6.0                6.0         2021-10-17
# 6                 7.0                7.0         2021-10-24
# 7                 8.0                8.0         2021-10-31
# 8                 9.0                9.0         2021-11-04
# 9                10.0               10.0         2021-11-14
# 10               11.0               11.0         2021-11-21
# 11               12.0               12.0         2021-11-28
# 12               13.0               13.0         2021-12-05
# 13               14.0               14.0         2021-12-18
# 14               15.0               15.0         2021-12-25
# 15               16.0               16.0         2022-01-02
# 16               17.0               17.0         2022-01-09
# 17                NaN                NaN              Total
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#    Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
#                    Tm Unnamed: 4_level_2                Opp
# 0                 IND                NaN                SEA
# 1                 IND                NaN                LAR
# 2                 IND                  @                TEN
# 3                 IND                  @                MIA
# 4                 IND                  @                BAL
# 5                 IND                NaN                HOU
# 6                 IND                  @                SFO
# 7                 IND                NaN                TEN
# 8                 IND                NaN                NYJ
# 9                 IND                NaN                JAX
# 10                IND                  @                BUF
# 11                IND                NaN                TAM
# 12                IND                  @                HOU
# 13                IND                NaN                NWE
# 14                IND                  @                ARI
# 15                IND                NaN                LVR
# 16                IND                  @                JAX
# 17                NaN                NaN                NaN
#
#    Unnamed: 6_level_0 Unnamed: 7_level_0 Inside 20       ... Inside 10  \
#    Unnamed: 6_level_1 Unnamed: 7_level_1   Rushing       ... Receiving
#                Result                Pos       Att  Yds  ...        TD
# 0             L 16-28                 RB         5   21  ...       0.0
# 1             L 24-27                 RB         7   16  ...       0.0
# 2             L 16-25                 RB         1    6  ...       0.0
# 3             W 27-17                 RB         6   10  ...       0.0
# 4             L 25-31                 RB         5    3  ...       0.0
# 5              W 31-3                 RB         4   16  ...       0.0
# 6             W 30-18                 RB         6    9  ...       0.0
# 7             L 31-34                 RB         3   16  ...       0.0
# 8             W 45-30                 RB         7   22  ...       0.0
# 9             W 23-17                 RB         6   30  ...       0.0
# 10            W 41-15                 RB        10   33  ...       0.0
# 11            L 31-38                 RB         4    9  ...       0.0
# 12             W 31-0                 RB         7   40  ...       0.0
# 13            W 27-17                 RB         6   14  ...       0.0
# 14            W 22-16                 RB         5    7  ...       0.0
# 15            L 20-23                 RB         1    1  ...       NaN
# 16            L 11-26                 RB         2   -2  ...       0.0
# 17                NaN                NaN        85  251  ...       0.0
#
#    Snap Counts                             Unnamed: 28_level_0  \
#           Off.        Def.        ST                   Fantasy
#            Num    Pct  Num   Pct Num   Pct              FantPt
# 0           42  55.3%    0  0.0%   0  0.0%                11.6
# 1           30  44.8%    0  0.0%   0  0.0%                 5.3
# 2           29  47.5%    0  0.0%   0  0.0%                 7.2
# 3           36  50.7%    0  0.0%   0  0.0%                17.4
# 4           36  52.2%    0  0.0%   0  0.0%                28.9
# 5           31  64.6%    0  0.0%   0  0.0%                27.8
# 6           47  69.1%    0  0.0%   0  0.0%                15.0
# 7           59  73.8%    0  0.0%   0  0.0%                18.2
# 8           43  69.4%    0  0.0%   0  0.0%                32.0
# 9           54  84.4%    0  0.0%   0  0.0%                18.6
# 10          57  82.6%    0  0.0%   0  0.0%                50.4
# 11          49  71.0%    0  0.0%   0  0.0%                15.7
# 12          55  76.4%    0  0.0%   0  0.0%                24.3
# 13          51  98.1%    0  0.0%   0  0.0%                23.0
# 14          55  78.6%    0  0.0%   0  0.0%                10.8
# 15          41  70.7%    0  0.0%   0  0.0%                17.4
# 16          52  91.2%    0  0.0%   0  0.0%                 9.5
# 17         767    NaN    0   NaN   0   NaN               333.1
#
#    Unnamed: 29_level_0 Unnamed: 30_level_0
#                Fantasy             Fantasy
#                   DKPt                FDPt
# 0                 17.6                14.6
# 1                  6.3                 5.8
# 2                  8.2                 7.7
# 3                 23.4                18.9
# 4                 34.9                30.4
# 5                 31.8                28.3
# 6                 22.0                16.5
# 7                 21.2                19.7
# 8                 37.0                33.0
# 9                 27.6                21.6
# 10                56.4                51.9
# 11                19.7                17.7
# 12                28.3                24.3
# 13                26.0                23.0
# 14                13.8                10.8
# 15                21.4                17.9
# 16                12.5                11.0
# 17               408.1               353.1
#
# [18 rows x 31 columns]
