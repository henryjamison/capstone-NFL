# %%
import pandas as pd

# url = 'https://www.pro-football-reference.com/players/M/MahoPa00/fantasy/'
# df = pd.read_html(url)[0]
# df
df_2022 = pd.read_csv('2022_fantasy.csv')
print(df_2022.to_html())

# %%
df_2021 = pd.read_csv('2021_fantasy.csv')
df_2021

# %%
# from bs4 import BeautifulSoup
# import requests

# url = 'https://www.pro-football-reference.com'
# year = 2018
# maxp = 300
    
# # grab fantasy players
# r = requests.get(url + '/years/' + str(year) + '/fantasy.htm')
# soup = BeautifulSoup(r.content, 'html.parser')
# parsed_table = soup.find_all('table')[0]  

# df = []

# # first 2 rows are col headers
# for i,row in enumerate(parsed_table.find_all('tr')[2:]):
#     if i % 10 == 0: print(i, end=' ')
#     if i >= maxp: 
#         print('\nComplete.')
#         break
        
#     try:
#         dat = row.find('td', attrs={'data-stat': 'player'})
#         name = dat.a.get_text()
#         stub = dat.a.get('href')
#         stub = stub[:-4] + '/fantasy/' + str(year)
#         pos = row.find('td', attrs={'data-stat': 'fantasy_pos'}).get_text()

#         # grab this players stats
#         tdf = pd.read_html(url + stub)[0]    

#         # get rid of MultiIndex, just keep last row
#         tdf.columns = tdf.columns.get_level_values(-1)

#         # fix the away/home column
#         tdf = tdf.rename(columns={'Unnamed: 4_level_2': 'Away'})
#         tdf['Away'] = [1 if r=='@' else 0 for r in tdf['Away']]

#         # drop all intermediate stats
#         tdf = tdf.iloc[:,[1,2,3,4,5,-3]]
        
#         # drop "Total" row
#         tdf = tdf.query('Date != "Total"')
        
#         # add other info
#         tdf['Name'] = name
#         tdf['Position'] = pos
#         tdf['Season'] = year

#         df.append(tdf)
#     except:
#         pass
    
# df = pd.concat(df)
# df.head()

# %%
df_2021['PlayerID']
# Out:
# 0      TaylJo02
# 1      KuppCo00
# 2      SamuDe00
# 3      AlleJo02
# 4      EkelAu00
#          ...
# 664    BenjTr00
# 665    CannTr00
# 666    WolfJo00
# 667    RoseJo01
# 668    SpenDi00
# Name: PlayerID, Length: 669, dtype: object

# %%
# user_id = df_2021['PlayerID'][0]
# year = 2021
# https://www.pro-football-reference.com/players/M/TaylJo02/fantasy/2021/
# url = 'https://www.pro-football-reference.com/players/M/{}/fantasy/{}/'.format(user_id,year)
# df = pd.read_html(url)[0]
# df
# html = requests.get(url).text
# soup = BeautifulSoup(html, 'html.parser')
# rows = soup.find('table').find_all('td')
# rows
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#    Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
#                    Rk                 G#               Date
# 0                 1.0                1.0         2021-09-12
# 1                 2.0                2.0         2021-09-19
# 2                 3.0                3.0         2021-09-26
# 3                 4.0                4.0         2021-10-03
# 4                 5.0                5.0         2021-10-11
# 5                 6.0                6.0         2021-10-17
# 6                 7.0                7.0         2021-10-24
# 7                 8.0                8.0         2021-10-31
# 8                 9.0                9.0         2021-11-04
# 9                10.0               10.0         2021-11-14
# 10               11.0               11.0         2021-11-21
# 11               12.0               12.0         2021-11-28
# 12               13.0               13.0         2021-12-05
# 13               14.0               14.0         2021-12-18
# 14               15.0               15.0         2021-12-25
# 15               16.0               16.0         2022-01-02
# 16               17.0               17.0         2022-01-09
# 17                NaN                NaN              Total
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#    Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
#                    Tm Unnamed: 4_level_2                Opp
# 0                 IND                NaN                SEA
# 1                 IND                NaN                LAR
# 2                 IND                  @                TEN
# 3                 IND                  @                MIA
# 4                 IND                  @                BAL
# 5                 IND                NaN                HOU
# 6                 IND                  @                SFO
# 7                 IND                NaN                TEN
# 8                 IND                NaN                NYJ
# 9                 IND                NaN                JAX
# 10                IND                  @                BUF
# 11                IND                NaN                TAM
# 12                IND                  @                HOU
# 13                IND                NaN                NWE
# 14                IND                  @                ARI
# 15                IND                NaN                LVR
# 16                IND                  @                JAX
# 17                NaN                NaN                NaN
#
#    Unnamed: 6_level_0 Unnamed: 7_level_0 Inside 20       ... Inside 10  \
#    Unnamed: 6_level_1 Unnamed: 7_level_1   Rushing       ... Receiving
#                Result                Pos       Att  Yds  ...        TD
# 0             L 16-28                 RB         5   21  ...       0.0
# 1             L 24-27                 RB         7   16  ...       0.0
# 2             L 16-25                 RB         1    6  ...       0.0
# 3             W 27-17                 RB         6   10  ...       0.0
# 4             L 25-31                 RB         5    3  ...       0.0
# 5              W 31-3                 RB         4   16  ...       0.0
# 6             W 30-18                 RB         6    9  ...       0.0
# 7             L 31-34                 RB         3   16  ...       0.0
# 8             W 45-30                 RB         7   22  ...       0.0
# 9             W 23-17                 RB         6   30  ...       0.0
# 10            W 41-15                 RB        10   33  ...       0.0
# 11            L 31-38                 RB         4    9  ...       0.0
# 12             W 31-0                 RB         7   40  ...       0.0
# 13            W 27-17                 RB         6   14  ...       0.0
# 14            W 22-16                 RB         5    7  ...       0.0
# 15            L 20-23                 RB         1    1  ...       NaN
# 16            L 11-26                 RB         2   -2  ...       0.0
# 17                NaN                NaN        85  251  ...       0.0
#
#    Snap Counts                             Unnamed: 28_level_0  \
#           Off.        Def.        ST                   Fantasy
#            Num    Pct  Num   Pct Num   Pct              FantPt
# 0           42  55.3%    0  0.0%   0  0.0%                11.6
# 1           30  44.8%    0  0.0%   0  0.0%                 5.3
# 2           29  47.5%    0  0.0%   0  0.0%                 7.2
# 3           36  50.7%    0  0.0%   0  0.0%                17.4
# 4           36  52.2%    0  0.0%   0  0.0%                28.9
# 5           31  64.6%    0  0.0%   0  0.0%                27.8
# 6           47  69.1%    0  0.0%   0  0.0%                15.0
# 7           59  73.8%    0  0.0%   0  0.0%                18.2
# 8           43  69.4%    0  0.0%   0  0.0%                32.0
# 9           54  84.4%    0  0.0%   0  0.0%                18.6
# 10          57  82.6%    0  0.0%   0  0.0%                50.4
# 11          49  71.0%    0  0.0%   0  0.0%                15.7
# 12          55  76.4%    0  0.0%   0  0.0%                24.3
# 13          51  98.1%    0  0.0%   0  0.0%                23.0
# 14          55  78.6%    0  0.0%   0  0.0%                10.8
# 15          41  70.7%    0  0.0%   0  0.0%                17.4
# 16          52  91.2%    0  0.0%   0  0.0%                 9.5
# 17         767    NaN    0   NaN   0   NaN               333.1
#
#    Unnamed: 29_level_0 Unnamed: 30_level_0
#                Fantasy             Fantasy
#                   DKPt                FDPt
# 0                 17.6                14.6
# 1                  6.3                 5.8
# 2                  8.2                 7.7
# 3                 23.4                18.9
# 4                 34.9                30.4
# 5                 31.8                28.3
# 6                 22.0                16.5
# 7                 21.2                19.7
# 8                 37.0                33.0
# 9                 27.6                21.6
# 10                56.4                51.9
# 11                19.7                17.7
# 12                28.3                24.3
# 13                26.0                23.0
# 14                13.8                10.8
# 15                21.4                17.9
# 16                12.5                11.0
# 17               408.1               353.1
#
# [18 rows x 31 columns]
